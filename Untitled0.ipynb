# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexandre0904/Exercicio-1/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("olá mundo!")
# Out:
# olá mundo!

# %% [markdown]
# Bom dia!
# ![image.png](data:image/png;base64,...)

# %%
tkm_19 = 320.52
Qtv_19 = 3

vtv_19 = tkm_19 * Qtv_19
print(vtv_19)
# Out:
# 961.56

# %%
vtv_20 = 834.47
tkm_20 = 119.21

Qtv = vtv_20 / tkm_20
print(int(Qtv))
# Out:
# 7

# %%
vtv_23 = 15378.12
Qtv_23 = 5

tkm = vtv_23 / Qtv_23
print(tkm)
# Out:
# 3075.6240000000003

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião'
x = cancao.count('')

print(x)
# Out:
# 49

# %%
cancao = cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
x = cancao.encode()

print(x)
# Out:
# b'Roda mundo, roda gigante, roda moinho, roda pi\xc3\xa3o.'

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
x = cancao.swapcase()

print(x)
# Out:
# rODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'
print(noticia[12:16])
print(noticia[62:63])
# Out:
# 2,75
# 6

# %%
a = False
b = True

x = not a & b
print(x)
# Out:
# True

# %%
filmes = ['Um Sonho de Liberdade', 'O Poderoso Chefão', 'Batmam', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schendler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction - Tempo de Violencia', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito' ]
print(filmes)
# Out:
# ['Um Sonho de Liberdade', 'O Poderoso Chefão', 'Batmam', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schendler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction - Tempo de Violencia', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito']

# %% [markdown]
# # Nova seção

# %% [markdown]
# # Nova seção

# %%
filmes = ['Um Sonho de Liberdade', 'O Poderoso Chefão', 'Batmam', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schendler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction - Tempo de Violencia', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito' ]
print(filmes)
# Out:
# ['Um Sonho de Liberdade', 'O Poderoso Chefão', 'Batmam', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schendler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction - Tempo de Violencia', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito']
